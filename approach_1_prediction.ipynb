# %%
import os
import glob
import time
import random
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import soundfile as sf  # to save denoised output as wav file

# %%
# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
random.seed(42)

# Parameters for audio processing
SR = 22050                # Sampling rate (Hz)
DURATION = 3              # Duration in seconds to load from each file
FIXED_LENGTH = SR * DURATION  # Number of samples per audio file
N_MELS = 128              # Number of Mel bands for spectrogram
HOP_LENGTH = 512          # Hop length for the STFT computation
# TIME_FRAMES = int(np.ceil(FIXED_LENGTH / HOP_LENGTH))  # Approximate time frames
TIME_FRAMES = 128  # Approximate time frames
# For PyTorch, input shape will be (channels, n_mels, time_frames)
INPUT_SHAPE = (1, N_MELS, TIME_FRAMES)  

# Directories for data (change these paths as needed; expecting WAV files now)
clean_dir = 'D:/projects/sound_ML/data/clean_testset_wav'   # Directory containing clean WAV files
noisy_dir = 'D:/projects/sound_ML/data/noisy_testset_wav'   # Directory containing noisy WAV files

# %%
def load_audio(file_path, sr=SR, duration=DURATION):
    """
    Load an audio file and pad or truncate it to FIXED_LENGTH samples.
    """
    try:
        y, _ = librosa.load(file_path, sr=sr, duration=duration)
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None
    if len(y) < FIXED_LENGTH:
        y = np.pad(y, (0, FIXED_LENGTH - len(y)), mode='constant')
    else:
        y = y[:FIXED_LENGTH]
    return y

def compute_mel_spectrogram(y, sr=SR, n_mels=N_MELS, hop_length=HOP_LENGTH):
    """
    Compute a Mel-spectrogram from an audio signal and convert it to a normalized log scale.
    """
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length)
    S_db = librosa.power_to_db(S, ref=np.max)  # Convert to dB scale
    # Normalize to [0,1] assuming dB values in [-80, 0]
    S_norm = (S_db + 80) / 80  
    return S_norm

def preprocess_file(file_path):
    y = load_audio(file_path)
    if y is None:
        return None
    mel_spec = compute_mel_spectrogram(y)
    # Crop or pad to TIME_FRAMES = 128
    if mel_spec.shape[1] < TIME_FRAMES:
        pad_width = TIME_FRAMES - mel_spec.shape[1]
        mel_spec = np.pad(mel_spec, ((0,0), (0, pad_width)), mode='constant')
    else:
        mel_spec = mel_spec[:, :TIME_FRAMES]
    mel_spec = np.expand_dims(mel_spec, axis=0)  # Shape: (1, n_mels, TIME_FRAMES)
    return mel_spec

# %%
def visualize_waveform(y, sr=SR, title="Waveform"):
    plt.figure(figsize=(10, 3))
    librosa.display.waveshow(y, sr=sr)
    plt.title(title)
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.tight_layout()
    plt.show()

def visualize_spectrogram(S, sr=SR, hop_length=HOP_LENGTH, title="Spectrogram"):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel')
    plt.title(title)
    plt.colorbar(format='%+2.0f dB')
    plt.tight_layout()
    plt.show()

# %%
clean_files = sorted(glob.glob(os.path.join(clean_dir, '*.wav')))
noisy_files = sorted(glob.glob(os.path.join(noisy_dir, '*.wav')))

print(f"Found {len(clean_files)} clean files and {len(noisy_files)} noisy files.")

# For a paired training set, use the minimum number of files available
num_files = min(len(clean_files), len(noisy_files))
print(f"Using {num_files} paired files for training.")

# Preprocess files: compute Mel-spectrograms for autoencoder training
clean_specs = []
noisy_specs = []

for i in range(num_files):
    clean_spec = preprocess_file(clean_files[i])
    noisy_spec = preprocess_file(noisy_files[i])
    if clean_spec is not None and noisy_spec is not None:
        clean_specs.append(clean_spec)
        noisy_specs.append(noisy_spec)
        print(f"File {i+1} preprocessed successfully.")

clean_specs = np.array(clean_specs)   # Shape: (num_files, 1, n_mels, time_frames)
noisy_specs = np.array(noisy_specs)

print("Clean spectrograms shape:", clean_specs.shape)
print("Noisy spectrograms shape:", noisy_specs.shape)

# Visualize a random example from each set
idx = np.random.randint(1, num_files)
visualize_waveform(load_audio(clean_files[idx]), title="Clean Audio Waveform")
visualize_spectrogram(np.squeeze(compute_mel_spectrogram(load_audio(clean_files[idx]))), title="Clean Audio Spectrogram")
visualize_waveform(load_audio(noisy_files[idx]), title="Noisy Audio Waveform")
visualize_spectrogram(np.squeeze(compute_mel_spectrogram(load_audio(noisy_files[idx]))), title="Noisy Audio Spectrogram")
# Out:
# Found 824 clean files and 824 noisy files.
# Using 824 paired files for training.
# File 1 preprocessed successfully.
# File 2 preprocessed successfully.
# File 3 preprocessed successfully.
# File 4 preprocessed successfully.
# File 5 preprocessed successfully.
# File 6 preprocessed successfully.
# File 7 preprocessed successfully.
# File 8 preprocessed successfully.
# File 9 preprocessed successfully.
# File 10 preprocessed successfully.
# File 11 preprocessed successfully.
# File 12 preprocessed successfully.
# File 13 preprocessed successfully.
# File 14 preprocessed successfully.
# File 15 preprocessed successfully.
# File 16 preprocessed successfully.
# File 17 preprocessed successfully.
# File 18 preprocessed successfully.
# File 19 preprocessed successfully.
# File 20 preprocessed successfully.
# File 21 preprocessed successfully.
# File 22 preprocessed successfully.
# File 23 preprocessed successfully.
# File 24 preprocessed successfully.
# File 25 preprocessed successfully.
# File 26 preprocessed successfully.
# File 27 preprocessed successfully.
# File 28 preprocessed successfully.
# File 29 preprocessed successfully.
# File 30 preprocessed successfully.
# File 31 preprocessed successfully.
# File 32 preprocessed successfully.
# File 33 preprocessed successfully.
# File 34 preprocessed successfully.
# File 35 preprocessed successfully.
# File 36 preprocessed successfully.
# File 37 preprocessed successfully.
# File 38 preprocessed successfully.
# File 39 preprocessed successfully.
# File 40 preprocessed successfully.
# File 41 preprocessed successfully.
# File 42 preprocessed successfully.
# File 43 preprocessed successfully.
# File 44 preprocessed successfully.
# File 45 preprocessed successfully.
# File 46 preprocessed successfully.
# File 47 preprocessed successfully.
# File 48 preprocessed successfully.
# File 49 preprocessed successfully.
# File 50 preprocessed successfully.
# File 51 preprocessed successfully.
# File 52 preprocessed successfully.
# File 53 preprocessed successfully.
# File 54 preprocessed successfully.
# File 55 preprocessed successfully.
# File 56 preprocessed successfully.
# File 57 preprocessed successfully.
# File 58 preprocessed successfully.
# File 59 preprocessed successfully.
# File 60 preprocessed successfully.
# File 61 preprocessed successfully.
# File 62 preprocessed successfully.
# File 63 preprocessed successfully.
# File 64 preprocessed successfully.
# File 65 preprocessed successfully.
# File 66 preprocessed successfully.
# File 67 preprocessed successfully.
# File 68 preprocessed successfully.
# File 69 preprocessed successfully.
# File 70 preprocessed successfully.
# File 71 preprocessed successfully.
# File 72 preprocessed successfully.
# File 73 preprocessed successfully.
# File 74 preprocessed successfully.
# File 75 preprocessed successfully.
# File 76 preprocessed successfully.
# File 77 preprocessed successfully.
# File 78 preprocessed successfully.
# File 79 preprocessed successfully.
# File 80 preprocessed successfully.
# File 81 preprocessed successfully.
# File 82 preprocessed successfully.
# File 83 preprocessed successfully.
# File 84 preprocessed successfully.
# File 85 preprocessed successfully.
# File 86 preprocessed successfully.
# File 87 preprocessed successfully.
# File 88 preprocessed successfully.
# File 89 preprocessed successfully.
# File 90 preprocessed successfully.
# File 91 preprocessed successfully.
# File 92 preprocessed successfully.
# File 93 preprocessed successfully.
# File 94 preprocessed successfully.
# File 95 preprocessed successfully.
# File 96 preprocessed successfully.
# File 97 preprocessed successfully.
# File 98 preprocessed successfully.
# File 99 preprocessed successfully.
# File 100 preprocessed successfully.
# File 101 preprocessed successfully.
# File 102 preprocessed successfully.
# File 103 preprocessed successfully.
# File 104 preprocessed successfully.
# File 105 preprocessed successfully.
# File 106 preprocessed successfully.
# File 107 preprocessed successfully.
# File 108 preprocessed successfully.
# File 109 preprocessed successfully.
# File 110 preprocessed successfully.
# File 111 preprocessed successfully.
# File 112 preprocessed successfully.
# File 113 preprocessed successfully.
# File 114 preprocessed successfully.
# File 115 preprocessed successfully.
# File 116 preprocessed successfully.
# File 117 preprocessed successfully.
# File 118 preprocessed successfully.
# File 119 preprocessed successfully.
# File 120 preprocessed successfully.
# File 121 preprocessed successfully.
# File 122 preprocessed successfully.
# File 123 preprocessed successfully.
# File 124 preprocessed successfully.
# File 125 preprocessed successfully.
# File 126 preprocessed successfully.
# File 127 preprocessed successfully.
# File 128 preprocessed successfully.
# File 129 preprocessed successfully.
# File 130 preprocessed successfully.
# File 131 preprocessed successfully.
# File 132 preprocessed successfully.
# File 133 preprocessed successfully.
# File 134 preprocessed successfully.
# File 135 preprocessed successfully.
# File 136 preprocessed successfully.
# File 137 preprocessed successfully.
# File 138 preprocessed successfully.
# File 139 preprocessed successfully.
# File 140 preprocessed successfully.
# File 141 preprocessed successfully.
# File 142 preprocessed successfully.
# File 143 preprocessed successfully.
# File 144 preprocessed successfully.
# File 145 preprocessed successfully.
# File 146 preprocessed successfully.
# File 147 preprocessed successfully.
# File 148 preprocessed successfully.
# File 149 preprocessed successfully.
# File 150 preprocessed successfully.
# File 151 preprocessed successfully.
# File 152 preprocessed successfully.
# File 153 preprocessed successfully.
# File 154 preprocessed successfully.
# File 155 preprocessed successfully.
# File 156 preprocessed successfully.
# File 157 preprocessed successfully.
# File 158 preprocessed successfully.
# File 159 preprocessed successfully.
# File 160 preprocessed successfully.
# File 161 preprocessed successfully.
# File 162 preprocessed successfully.
# File 163 preprocessed successfully.
# File 164 preprocessed successfully.
# File 165 preprocessed successfully.
# File 166 preprocessed successfully.
# File 167 preprocessed successfully.
# File 168 preprocessed successfully.
# File 169 preprocessed successfully.
# File 170 preprocessed successfully.
# File 171 preprocessed successfully.
# File 172 preprocessed successfully.
# File 173 preprocessed successfully.
# File 174 preprocessed successfully.
# File 175 preprocessed successfully.
# File 176 preprocessed successfully.
# File 177 preprocessed successfully.
# File 178 preprocessed successfully.
# File 179 preprocessed successfully.
# File 180 preprocessed successfully.
# File 181 preprocessed successfully.
# File 182 preprocessed successfully.
# File 183 preprocessed successfully.
# File 184 preprocessed successfully.
# File 185 preprocessed successfully.
# File 186 preprocessed successfully.
# File 187 preprocessed successfully.
# File 188 preprocessed successfully.
# File 189 preprocessed successfully.
# File 190 preprocessed successfully.
# File 191 preprocessed successfully.
# File 192 preprocessed successfully.
# File 193 preprocessed successfully.
# File 194 preprocessed successfully.
# File 195 preprocessed successfully.
# File 196 preprocessed successfully.
# File 197 preprocessed successfully.
# File 198 preprocessed successfully.
# File 199 preprocessed successfully.
# File 200 preprocessed successfully.
# File 201 preprocessed successfully.
# File 202 preprocessed successfully.
# File 203 preprocessed successfully.
# File 204 preprocessed successfully.
# File 205 preprocessed successfully.
# File 206 preprocessed successfully.
# File 207 preprocessed successfully.
# File 208 preprocessed successfully.
# File 209 preprocessed successfully.
# File 210 preprocessed successfully.
# File 211 preprocessed successfully.
# File 212 preprocessed successfully.
# File 213 preprocessed successfully.
# File 214 preprocessed successfully.
# File 215 preprocessed successfully.
# File 216 preprocessed successfully.
# File 217 preprocessed successfully.
# File 218 preprocessed successfully.
# File 219 preprocessed successfully.
# File 220 preprocessed successfully.
# File 221 preprocessed successfully.
# File 222 preprocessed successfully.
# File 223 preprocessed successfully.
# File 224 preprocessed successfully.
# File 225 preprocessed successfully.
# File 226 preprocessed successfully.
# File 227 preprocessed successfully.
# File 228 preprocessed successfully.
# File 229 preprocessed successfully.
# File 230 preprocessed successfully.
# File 231 preprocessed successfully.
# File 232 preprocessed successfully.
# File 233 preprocessed successfully.
# File 234 preprocessed successfully.
# File 235 preprocessed successfully.
# File 236 preprocessed successfully.
# File 237 preprocessed successfully.
# File 238 preprocessed successfully.
# File 239 preprocessed successfully.
# File 240 preprocessed successfully.
# File 241 preprocessed successfully.
# File 242 preprocessed successfully.
# File 243 preprocessed successfully.
# File 244 preprocessed successfully.
# File 245 preprocessed successfully.
# File 246 preprocessed successfully.
# File 247 preprocessed successfully.
# File 248 preprocessed successfully.
# File 249 preprocessed successfully.
# File 250 preprocessed successfully.
# File 251 preprocessed successfully.
# File 252 preprocessed successfully.
# File 253 preprocessed successfully.
# File 254 preprocessed successfully.
# File 255 preprocessed successfully.
# File 256 preprocessed successfully.
# File 257 preprocessed successfully.
# File 258 preprocessed successfully.
# File 259 preprocessed successfully.
# File 260 preprocessed successfully.
# File 261 preprocessed successfully.
# File 262 preprocessed successfully.
# File 263 preprocessed successfully.
# File 264 preprocessed successfully.
# File 265 preprocessed successfully.
# File 266 preprocessed successfully.
# File 267 preprocessed successfully.
# File 268 preprocessed successfully.
# File 269 preprocessed successfully.
# File 270 preprocessed successfully.
# File 271 preprocessed successfully.
# File 272 preprocessed successfully.
# File 273 preprocessed successfully.
# File 274 preprocessed successfully.
# File 275 preprocessed successfully.
# File 276 preprocessed successfully.
# File 277 preprocessed successfully.
# File 278 preprocessed successfully.
# File 279 preprocessed successfully.
# File 280 preprocessed successfully.
# File 281 preprocessed successfully.
# File 282 preprocessed successfully.
# File 283 preprocessed successfully.
# File 284 preprocessed successfully.
# File 285 preprocessed successfully.
# File 286 preprocessed successfully.
# File 287 preprocessed successfully.
# File 288 preprocessed successfully.
# File 289 preprocessed successfully.
# File 290 preprocessed successfully.
# File 291 preprocessed successfully.
# File 292 preprocessed successfully.
# File 293 preprocessed successfully.
# File 294 preprocessed successfully.
# File 295 preprocessed successfully.
# File 296 preprocessed successfully.
# File 297 preprocessed successfully.
# File 298 preprocessed successfully.
# File 299 preprocessed successfully.
# File 300 preprocessed successfully.
# File 301 preprocessed successfully.
# File 302 preprocessed successfully.
# File 303 preprocessed successfully.
# File 304 preprocessed successfully.
# File 305 preprocessed successfully.
# File 306 preprocessed successfully.
# File 307 preprocessed successfully.
# File 308 preprocessed successfully.
# File 309 preprocessed successfully.
# File 310 preprocessed successfully.
# File 311 preprocessed successfully.
# File 312 preprocessed successfully.
# File 313 preprocessed successfully.
# File 314 preprocessed successfully.
# File 315 preprocessed successfully.
# File 316 preprocessed successfully.
# File 317 preprocessed successfully.
# File 318 preprocessed successfully.
# File 319 preprocessed successfully.
# File 320 preprocessed successfully.
# File 321 preprocessed successfully.
# File 322 preprocessed successfully.
# File 323 preprocessed successfully.
# File 324 preprocessed successfully.
# File 325 preprocessed successfully.
# File 326 preprocessed successfully.
# File 327 preprocessed successfully.
# File 328 preprocessed successfully.
# File 329 preprocessed successfully.
# File 330 preprocessed successfully.
# File 331 preprocessed successfully.
# File 332 preprocessed successfully.
# File 333 preprocessed successfully.
# File 334 preprocessed successfully.
# File 335 preprocessed successfully.
# File 336 preprocessed successfully.
# File 337 preprocessed successfully.
# File 338 preprocessed successfully.
# File 339 preprocessed successfully.
# File 340 preprocessed successfully.
# File 341 preprocessed successfully.
# File 342 preprocessed successfully.
# File 343 preprocessed successfully.
# File 344 preprocessed successfully.
# File 345 preprocessed successfully.
# File 346 preprocessed successfully.
# File 347 preprocessed successfully.
# File 348 preprocessed successfully.
# File 349 preprocessed successfully.
# File 350 preprocessed successfully.
# File 351 preprocessed successfully.
# File 352 preprocessed successfully.
# File 353 preprocessed successfully.
# File 354 preprocessed successfully.
# File 355 preprocessed successfully.
# File 356 preprocessed successfully.
# File 357 preprocessed successfully.
# File 358 preprocessed successfully.
# File 359 preprocessed successfully.
# File 360 preprocessed successfully.
# File 361 preprocessed successfully.
# File 362 preprocessed successfully.
# File 363 preprocessed successfully.
# File 364 preprocessed successfully.
# File 365 preprocessed successfully.
# File 366 preprocessed successfully.
# File 367 preprocessed successfully.
# File 368 preprocessed successfully.
# File 369 preprocessed successfully.
# File 370 preprocessed successfully.
# File 371 preprocessed successfully.
# File 372 preprocessed successfully.
# File 373 preprocessed successfully.
# File 374 preprocessed successfully.
# File 375 preprocessed successfully.
# File 376 preprocessed successfully.
# File 377 preprocessed successfully.
# File 378 preprocessed successfully.
# File 379 preprocessed successfully.
# File 380 preprocessed successfully.
# File 381 preprocessed successfully.
# File 382 preprocessed successfully.
# File 383 preprocessed successfully.
# File 384 preprocessed successfully.
# File 385 preprocessed successfully.
# File 386 preprocessed successfully.
# File 387 preprocessed successfully.
# File 388 preprocessed successfully.
# File 389 preprocessed successfully.
# File 390 preprocessed successfully.
# File 391 preprocessed successfully.
# File 392 preprocessed successfully.
# File 393 preprocessed successfully.
# File 394 preprocessed successfully.
# File 395 preprocessed successfully.
# File 396 preprocessed successfully.
# File 397 preprocessed successfully.
# File 398 preprocessed successfully.
# File 399 preprocessed successfully.
# File 400 preprocessed successfully.
# File 401 preprocessed successfully.
# File 402 preprocessed successfully.
# File 403 preprocessed successfully.
# File 404 preprocessed successfully.
# File 405 preprocessed successfully.
# File 406 preprocessed successfully.
# File 407 preprocessed successfully.
# File 408 preprocessed successfully.
# File 409 preprocessed successfully.
# File 410 preprocessed successfully.
# File 411 preprocessed successfully.
# File 412 preprocessed successfully.
# File 413 preprocessed successfully.
# File 414 preprocessed successfully.
# File 415 preprocessed successfully.
# File 416 preprocessed successfully.
# File 417 preprocessed successfully.
# File 418 preprocessed successfully.
# File 419 preprocessed successfully.
# File 420 preprocessed successfully.
# File 421 preprocessed successfully.
# File 422 preprocessed successfully.
# File 423 preprocessed successfully.
# File 424 preprocessed successfully.
# File 425 preprocessed successfully.
# File 426 preprocessed successfully.
# File 427 preprocessed successfully.
# File 428 preprocessed successfully.
# File 429 preprocessed successfully.
# File 430 preprocessed successfully.
# File 431 preprocessed successfully.
# File 432 preprocessed successfully.
# File 433 preprocessed successfully.
# File 434 preprocessed successfully.
# File 435 preprocessed successfully.
# File 436 preprocessed successfully.
# File 437 preprocessed successfully.
# File 438 preprocessed successfully.
# File 439 preprocessed successfully.
# File 440 preprocessed successfully.
# File 441 preprocessed successfully.
# File 442 preprocessed successfully.
# File 443 preprocessed successfully.
# File 444 preprocessed successfully.
# File 445 preprocessed successfully.
# File 446 preprocessed successfully.
# File 447 preprocessed successfully.
# File 448 preprocessed successfully.
# File 449 preprocessed successfully.
# File 450 preprocessed successfully.
# File 451 preprocessed successfully.
# File 452 preprocessed successfully.
# File 453 preprocessed successfully.
# File 454 preprocessed successfully.
# File 455 preprocessed successfully.
# File 456 preprocessed successfully.
# File 457 preprocessed successfully.
# File 458 preprocessed successfully.
# File 459 preprocessed successfully.
# File 460 preprocessed successfully.
# File 461 preprocessed successfully.
# File 462 preprocessed successfully.
# File 463 preprocessed successfully.
# File 464 preprocessed successfully.
# File 465 preprocessed successfully.
# File 466 preprocessed successfully.
# File 467 preprocessed successfully.
# File 468 preprocessed successfully.
# File 469 preprocessed successfully.
# File 470 preprocessed successfully.
# File 471 preprocessed successfully.
# File 472 preprocessed successfully.
# File 473 preprocessed successfully.
# File 474 preprocessed successfully.
# File 475 preprocessed successfully.
# File 476 preprocessed successfully.
# File 477 preprocessed successfully.
# File 478 preprocessed successfully.
# File 479 preprocessed successfully.
# File 480 preprocessed successfully.
# File 481 preprocessed successfully.
# File 482 preprocessed successfully.
# File 483 preprocessed successfully.
# File 484 preprocessed successfully.
# File 485 preprocessed successfully.
# File 486 preprocessed successfully.
# File 487 preprocessed successfully.
# File 488 preprocessed successfully.
# File 489 preprocessed successfully.
# File 490 preprocessed successfully.
# File 491 preprocessed successfully.
# File 492 preprocessed successfully.
# File 493 preprocessed successfully.
# File 494 preprocessed successfully.
# File 495 preprocessed successfully.
# File 496 preprocessed successfully.
# File 497 preprocessed successfully.
# File 498 preprocessed successfully.
# File 499 preprocessed successfully.
# File 500 preprocessed successfully.
# File 501 preprocessed successfully.
# File 502 preprocessed successfully.
# File 503 preprocessed successfully.
# File 504 preprocessed successfully.
# File 505 preprocessed successfully.
# File 506 preprocessed successfully.
# File 507 preprocessed successfully.
# File 508 preprocessed successfully.
# File 509 preprocessed successfully.
# File 510 preprocessed successfully.
# File 511 preprocessed successfully.
# File 512 preprocessed successfully.
# File 513 preprocessed successfully.
# File 514 preprocessed successfully.
# File 515 preprocessed successfully.
# File 516 preprocessed successfully.
# File 517 preprocessed successfully.
# File 518 preprocessed successfully.
# File 519 preprocessed successfully.
# File 520 preprocessed successfully.
# File 521 preprocessed successfully.
# File 522 preprocessed successfully.
# File 523 preprocessed successfully.
# File 524 preprocessed successfully.
# File 525 preprocessed successfully.
# File 526 preprocessed successfully.
# File 527 preprocessed successfully.
# File 528 preprocessed successfully.
# File 529 preprocessed successfully.
# File 530 preprocessed successfully.
# File 531 preprocessed successfully.
# File 532 preprocessed successfully.
# File 533 preprocessed successfully.
# File 534 preprocessed successfully.
# File 535 preprocessed successfully.
# File 536 preprocessed successfully.
# File 537 preprocessed successfully.
# File 538 preprocessed successfully.
# File 539 preprocessed successfully.
# File 540 preprocessed successfully.
# File 541 preprocessed successfully.
# File 542 preprocessed successfully.
# File 543 preprocessed successfully.
# File 544 preprocessed successfully.
# File 545 preprocessed successfully.
# File 546 preprocessed successfully.
# File 547 preprocessed successfully.
# File 548 preprocessed successfully.
# File 549 preprocessed successfully.
# File 550 preprocessed successfully.
# File 551 preprocessed successfully.
# File 552 preprocessed successfully.
# File 553 preprocessed successfully.
# File 554 preprocessed successfully.
# File 555 preprocessed successfully.
# File 556 preprocessed successfully.
# File 557 preprocessed successfully.
# File 558 preprocessed successfully.
# File 559 preprocessed successfully.
# File 560 preprocessed successfully.
# File 561 preprocessed successfully.
# File 562 preprocessed successfully.
# File 563 preprocessed successfully.
# File 564 preprocessed successfully.
# File 565 preprocessed successfully.
# File 566 preprocessed successfully.
# File 567 preprocessed successfully.
# File 568 preprocessed successfully.
# File 569 preprocessed successfully.
# File 570 preprocessed successfully.
# File 571 preprocessed successfully.
# File 572 preprocessed successfully.
# File 573 preprocessed successfully.
# File 574 preprocessed successfully.
# File 575 preprocessed successfully.
# File 576 preprocessed successfully.
# File 577 preprocessed successfully.
# File 578 preprocessed successfully.
# File 579 preprocessed successfully.
# File 580 preprocessed successfully.
# File 581 preprocessed successfully.
# File 582 preprocessed successfully.
# File 583 preprocessed successfully.
# File 584 preprocessed successfully.
# File 585 preprocessed successfully.
# File 586 preprocessed successfully.
# File 587 preprocessed successfully.
# File 588 preprocessed successfully.
# File 589 preprocessed successfully.
# File 590 preprocessed successfully.
# File 591 preprocessed successfully.
# File 592 preprocessed successfully.
# File 593 preprocessed successfully.
# File 594 preprocessed successfully.
# File 595 preprocessed successfully.
# File 596 preprocessed successfully.
# File 597 preprocessed successfully.
# File 598 preprocessed successfully.
# File 599 preprocessed successfully.
# File 600 preprocessed successfully.
# File 601 preprocessed successfully.
# File 602 preprocessed successfully.
# File 603 preprocessed successfully.
# File 604 preprocessed successfully.
# File 605 preprocessed successfully.
# File 606 preprocessed successfully.
# File 607 preprocessed successfully.
# File 608 preprocessed successfully.
# File 609 preprocessed successfully.
# File 610 preprocessed successfully.
# File 611 preprocessed successfully.
# File 612 preprocessed successfully.
# File 613 preprocessed successfully.
# File 614 preprocessed successfully.
# File 615 preprocessed successfully.
# File 616 preprocessed successfully.
# File 617 preprocessed successfully.
# File 618 preprocessed successfully.
# File 619 preprocessed successfully.
# File 620 preprocessed successfully.
# File 621 preprocessed successfully.
# File 622 preprocessed successfully.
# File 623 preprocessed successfully.
# File 624 preprocessed successfully.
# File 625 preprocessed successfully.
# File 626 preprocessed successfully.
# File 627 preprocessed successfully.
# File 628 preprocessed successfully.
# File 629 preprocessed successfully.
# File 630 preprocessed successfully.
# File 631 preprocessed successfully.
# File 632 preprocessed successfully.
# File 633 preprocessed successfully.
# File 634 preprocessed successfully.
# File 635 preprocessed successfully.
# File 636 preprocessed successfully.
# File 637 preprocessed successfully.
# File 638 preprocessed successfully.
# File 639 preprocessed successfully.
# File 640 preprocessed successfully.
# File 641 preprocessed successfully.
# File 642 preprocessed successfully.
# File 643 preprocessed successfully.
# File 644 preprocessed successfully.
# File 645 preprocessed successfully.
# File 646 preprocessed successfully.
# File 647 preprocessed successfully.
# File 648 preprocessed successfully.
# File 649 preprocessed successfully.
# File 650 preprocessed successfully.
# File 651 preprocessed successfully.
# File 652 preprocessed successfully.
# File 653 preprocessed successfully.
# File 654 preprocessed successfully.
# File 655 preprocessed successfully.
# File 656 preprocessed successfully.
# File 657 preprocessed successfully.
# File 658 preprocessed successfully.
# File 659 preprocessed successfully.
# File 660 preprocessed successfully.
# File 661 preprocessed successfully.
# File 662 preprocessed successfully.
# File 663 preprocessed successfully.
# File 664 preprocessed successfully.
# File 665 preprocessed successfully.
# File 666 preprocessed successfully.
# File 667 preprocessed successfully.
# File 668 preprocessed successfully.
# File 669 preprocessed successfully.
# File 670 preprocessed successfully.
# File 671 preprocessed successfully.
# File 672 preprocessed successfully.
# File 673 preprocessed successfully.
# File 674 preprocessed successfully.
# File 675 preprocessed successfully.
# File 676 preprocessed successfully.
# File 677 preprocessed successfully.
# File 678 preprocessed successfully.
# File 679 preprocessed successfully.
# File 680 preprocessed successfully.
# File 681 preprocessed successfully.
# File 682 preprocessed successfully.
# File 683 preprocessed successfully.
# File 684 preprocessed successfully.
# File 685 preprocessed successfully.
# File 686 preprocessed successfully.
# File 687 preprocessed successfully.
# File 688 preprocessed successfully.
# File 689 preprocessed successfully.
# File 690 preprocessed successfully.
# File 691 preprocessed successfully.
# File 692 preprocessed successfully.
# File 693 preprocessed successfully.
# File 694 preprocessed successfully.
# File 695 preprocessed successfully.
# File 696 preprocessed successfully.
# File 697 preprocessed successfully.
# File 698 preprocessed successfully.
# File 699 preprocessed successfully.
# File 700 preprocessed successfully.
# File 701 preprocessed successfully.
# File 702 preprocessed successfully.
# File 703 preprocessed successfully.
# File 704 preprocessed successfully.
# File 705 preprocessed successfully.
# File 706 preprocessed successfully.
# File 707 preprocessed successfully.
# File 708 preprocessed successfully.
# File 709 preprocessed successfully.
# File 710 preprocessed successfully.
# File 711 preprocessed successfully.
# File 712 preprocessed successfully.
# File 713 preprocessed successfully.
# File 714 preprocessed successfully.
# File 715 preprocessed successfully.
# File 716 preprocessed successfully.
# File 717 preprocessed successfully.
# File 718 preprocessed successfully.
# File 719 preprocessed successfully.
# File 720 preprocessed successfully.
# File 721 preprocessed successfully.
# File 722 preprocessed successfully.
# File 723 preprocessed successfully.
# File 724 preprocessed successfully.
# File 725 preprocessed successfully.
# File 726 preprocessed successfully.
# File 727 preprocessed successfully.
# File 728 preprocessed successfully.
# File 729 preprocessed successfully.
# File 730 preprocessed successfully.
# File 731 preprocessed successfully.
# File 732 preprocessed successfully.
# File 733 preprocessed successfully.
# File 734 preprocessed successfully.
# File 735 preprocessed successfully.
# File 736 preprocessed successfully.
# File 737 preprocessed successfully.
# File 738 preprocessed successfully.
# File 739 preprocessed successfully.
# File 740 preprocessed successfully.
# File 741 preprocessed successfully.
# File 742 preprocessed successfully.
# File 743 preprocessed successfully.
# File 744 preprocessed successfully.
# File 745 preprocessed successfully.
# File 746 preprocessed successfully.
# File 747 preprocessed successfully.
# File 748 preprocessed successfully.
# File 749 preprocessed successfully.
# File 750 preprocessed successfully.
# File 751 preprocessed successfully.
# File 752 preprocessed successfully.
# File 753 preprocessed successfully.
# File 754 preprocessed successfully.
# File 755 preprocessed successfully.
# File 756 preprocessed successfully.
# File 757 preprocessed successfully.
# File 758 preprocessed successfully.
# File 759 preprocessed successfully.
# File 760 preprocessed successfully.
# File 761 preprocessed successfully.
# File 762 preprocessed successfully.
# File 763 preprocessed successfully.
# File 764 preprocessed successfully.
# File 765 preprocessed successfully.
# File 766 preprocessed successfully.
# File 767 preprocessed successfully.
# File 768 preprocessed successfully.
# File 769 preprocessed successfully.
# File 770 preprocessed successfully.
# File 771 preprocessed successfully.
# File 772 preprocessed successfully.
# File 773 preprocessed successfully.
# File 774 preprocessed successfully.
# File 775 preprocessed successfully.
# File 776 preprocessed successfully.
# File 777 preprocessed successfully.
# File 778 preprocessed successfully.
# File 779 preprocessed successfully.
# File 780 preprocessed successfully.
# File 781 preprocessed successfully.
# File 782 preprocessed successfully.
# File 783 preprocessed successfully.
# File 784 preprocessed successfully.
# File 785 preprocessed successfully.
# File 786 preprocessed successfully.
# File 787 preprocessed successfully.
# File 788 preprocessed successfully.
# File 789 preprocessed successfully.
# File 790 preprocessed successfully.
# File 791 preprocessed successfully.
# File 792 preprocessed successfully.
# File 793 preprocessed successfully.
# File 794 preprocessed successfully.
# File 795 preprocessed successfully.
# File 796 preprocessed successfully.
# File 797 preprocessed successfully.
# File 798 preprocessed successfully.
# File 799 preprocessed successfully.
# File 800 preprocessed successfully.
# File 801 preprocessed successfully.
# File 802 preprocessed successfully.
# File 803 preprocessed successfully.
# File 804 preprocessed successfully.
# File 805 preprocessed successfully.
# File 806 preprocessed successfully.
# File 807 preprocessed successfully.
# File 808 preprocessed successfully.
# File 809 preprocessed successfully.
# File 810 preprocessed successfully.
# File 811 preprocessed successfully.
# File 812 preprocessed successfully.
# File 813 preprocessed successfully.
# File 814 preprocessed successfully.
# File 815 preprocessed successfully.
# File 816 preprocessed successfully.
# File 817 preprocessed successfully.
# File 818 preprocessed successfully.
# File 819 preprocessed successfully.
# File 820 preprocessed successfully.
# File 821 preprocessed successfully.
# File 822 preprocessed successfully.
# File 823 preprocessed successfully.
# File 824 preprocessed successfully.
# Clean spectrograms shape: (824, 1, 128, 128)
# Noisy spectrograms shape: (824, 1, 128, 128)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    noisy_specs, clean_specs, test_size=0.2, random_state=42
)
print("Training set:", X_train.shape, y_train.shape)
print("Validation set:", X_val.shape, y_val.shape)
# Out:
# Training set: (659, 1, 128, 128) (659, 1, 128, 128)
# Validation set: (165, 1, 128, 128) (165, 1, 128, 128)

# %%
class AudioDataset(Dataset):
    def __init__(self, noisy_data, clean_data):
        self.noisy = torch.tensor(noisy_data, dtype=torch.float32)
        self.clean = torch.tensor(clean_data, dtype=torch.float32)
    
    def __len__(self):
        return len(self.noisy)
    
    def __getitem__(self, idx):
        return self.noisy[idx], self.clean[idx]

batch_size = 8
train_dataset = AudioDataset(X_train, y_train)
val_dataset = AudioDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class DenoisingAutoencoder(nn.Module):
    def __init__(self):
        super(DenoisingAutoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # (batch, 32, n_mels, time_frames)
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2, padding=0),         # (batch, 32, n_mels/2, time_frames/2)
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2, padding=0)          # (batch, 64, n_mels/4, time_frames/4)
        )
        # Decoder
        self.decoder = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(32, 1, kernel_size=3, padding=1),
            nn.Sigmoid()  # output normalized between [0,1]
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Create model instance and move to device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DenoisingAutoencoder().to(device)
print(model)

# Define loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
# Out:
# DenoisingAutoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Upsample(scale_factor=2.0, mode='nearest')
#     (3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Upsample(scale_factor=2.0, mode='nearest')
#     (6): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): Sigmoid()
#   )
# )

# %%
num_epochs = 10
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for noisy_batch, clean_batch in train_loader:
        noisy_batch = noisy_batch.to(device)
        clean_batch = clean_batch.to(device)
        
        optimizer.zero_grad()
        outputs = model(noisy_batch)
        loss = criterion(outputs, clean_batch)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * noisy_batch.size(0)
    epoch_train_loss = running_loss / len(train_dataset)
    train_losses.append(epoch_train_loss)
    
    # Validation
    model.eval()
    val_running_loss = 0.0
    with torch.no_grad():
        for noisy_batch, clean_batch in val_loader:
            noisy_batch = noisy_batch.to(device)
            clean_batch = clean_batch.to(device)
            outputs = model(noisy_batch)
            loss = criterion(outputs, clean_batch)
            val_running_loss += loss.item() * noisy_batch.size(0)
    epoch_val_loss = val_running_loss / len(val_dataset)
    val_losses.append(epoch_val_loss)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")
# Out:
# Epoch [1/10], Train Loss: 0.0294, Val Loss: 0.0173
# Epoch [2/10], Train Loss: 0.0124, Val Loss: 0.0103
# Epoch [3/10], Train Loss: 0.0100, Val Loss: 0.0088
# Epoch [4/10], Train Loss: 0.0092, Val Loss: 0.0089
# Epoch [5/10], Train Loss: 0.0084, Val Loss: 0.0076
# Epoch [6/10], Train Loss: 0.0079, Val Loss: 0.0073
# Epoch [7/10], Train Loss: 0.0077, Val Loss: 0.0078
# Epoch [8/10], Train Loss: 0.0074, Val Loss: 0.0069
# Epoch [9/10], Train Loss: 0.0071, Val Loss: 0.0068
# Epoch [10/10], Train Loss: 0.0069, Val Loss: 0.0067

# %%
# ===============================
# 1. IMPORT LIBRARIES & SET PARAMETERS
# ===============================



# ===============================
# 2. DEFINE AUDIO PREPROCESSING FUNCTIONS
# ===============================


# ===============================
# 3. VISUALIZE RAW AUDIO AND SPECTROGRAMS
# ===============================


# ===============================
# 4. LOAD DATASET (CLEAN & NOISY) AND PREPROCESS
# ===============================
# Get file paths (assuming WAV files; adjust glob pattern as needed)


# ===============================
# 5. SPLIT DATA INTO TRAINING AND VALIDATION SETS
# ===============================


# ===============================
# 6. CREATE A CUSTOM PYTORCH DATASET & DATALOADER
# ===============================


# ===============================
# 7. BUILD THE DENOISING AUTOENCODER MODEL IN PYTORCH
# ===============================

# ===============================
# 8. TRAIN THE MODEL
# ===============================


# ===============================
# 9. PLOT TRAINING & VALIDATION LOSSES
# ===============================
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Autoencoder Training Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import torch
import soundfile as sf
import matplotlib.pyplot as plt

def smooth_audio(y, window_len=101, window='hanning'):
    """
    Smooth a 1D array using convolution with a window.
    
    Parameters:
      - y: 1D numpy array (audio waveform)
      - window_len: Length of the smoothing window (should be an odd integer)
      - window: Type of window from ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']
                'flat' will produce a moving average.
    Returns:
      - y_smooth: Smoothed 1D numpy array.
    """
    if y.ndim != 1:
        raise ValueError("smooth_audio only accepts 1D arrays.")
    if y.size < window_len:
        return y  # no smoothing if array is too short
    if window == 'flat':  # moving average
        w = np.ones(window_len)
    else:
        w = getattr(np, window)(window_len)
    # Normalize the window
    w /= w.sum()
    # Apply convolution; use mode 'same' for simplicity
    y_smooth = np.convolve(y, w, mode='same')
    return y_smooth

def denoise_audio_full(input_wav_path, output_wav_path, model, 
                       sr=SR, chunk_duration=DURATION, 
                       gain=50, n_iter=128, db_range=70, smooth_window=101):
    """
    Processes a long input audio file by splitting it into fixed-length segments 
    (chunk_duration seconds), denoising each segment with the model, and concatenating 
    the results. Applies a smoothing filter to the final waveform.
    
    Parameters:
      - input_wav_path: Path to the input (noisy) WAV file.
      - output_wav_path: Path to save the denoised output.
      - model: The trained autoencoder model.
      - sr: Sampling rate.
      - chunk_duration: Duration (in seconds) for each segment (should match training duration).
      - gain: Post-processing gain factor.
      - n_iter: Number of Griffin-Lim iterations.
      - db_range: Dynamic range used for normalization (e.g. 60 dB).
      - smooth_window: Window length for smoothing filter.
    """
    # Load full audio
    y_full, sr = librosa.load(input_wav_path, sr=sr)
    chunk_length = int(sr * chunk_duration)
    segments = []
    
    # Split audio into chunks (non-overlapping)
    for start in range(0, len(y_full), chunk_length):
        seg = y_full[start: start + chunk_length]
        # If the last segment is shorter than chunk_length, pad it with zeros
        if len(seg) < chunk_length:
            seg = np.pad(seg, (0, chunk_length - len(seg)), mode='constant')
        segments.append(seg)
    
    denoised_segments = []
    
    # Process each segment
    for seg in segments:
        # Compute Mel-spectrogram for the segment
        mel_spec = compute_mel_spectrogram(seg)
        # Crop or pad mel_spec to fixed TIME_FRAMES
        if mel_spec.shape[1] < TIME_FRAMES:
            pad_width = TIME_FRAMES - mel_spec.shape[1]
            mel_spec = np.pad(mel_spec, ((0, 0), (0, pad_width)), mode='constant')
        else:
            mel_spec = mel_spec[:, :TIME_FRAMES]
        # Expand dims for (1, n_mels, TIME_FRAMES)
        mel_spec = np.expand_dims(mel_spec, axis=0)
        # Convert to tensor and add batch dimension: (1, 1, n_mels, TIME_FRAMES)
        input_tensor = torch.tensor(mel_spec, dtype=torch.float32).unsqueeze(0).to(device)
        
        # Run the autoencoder on the segment
        model.eval()
        with torch.no_grad():
            denoised_tensor = model(input_tensor)
        # Remove batch and channel dimensions -> shape: (n_mels, TIME_FRAMES)
        denoised_mel = denoised_tensor.squeeze().cpu().numpy()
        # Invert normalization: map from [0, 1] to [-db_range, 0] dB
        denoised_db = denoised_mel * db_range - db_range
        # Convert from dB to power (linear scale)
        denoised_power = librosa.db_to_power(denoised_db)
        
        # Reconstruct waveform using Griffin-Lim with increased iterations
        seg_denoised = librosa.feature.inverse.mel_to_audio(
            denoised_power, sr=sr, n_iter=n_iter, hop_length=HOP_LENGTH, n_fft=2048
        )
        # Apply gain adjustment and clip to avoid artifacts
        seg_denoised = seg_denoised * gain
        seg_denoised = np.clip(seg_denoised, -1.0, 1.0)
        
        denoised_segments.append(seg_denoised)
    
    # Concatenate all denoised segments
    y_denoised_full = np.concatenate(denoised_segments)
    
    # Apply smoothing filter to the final waveform
    y_denoised_full = smooth_audio(y_denoised_full, window_len=smooth_window, window='hanning')
    
    # Save the output audio file with explicit format/subtype
    sf.write(output_wav_path, y_denoised_full, sr, format='WAV', subtype='PCM_16')
    print(f"Denoised full audio saved to: {output_wav_path}")
    
    # Plot comparison for the first segment
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    librosa.display.waveshow(segments[0], sr=sr)
    plt.title("Noisy Segment (First Chunk)")
    plt.subplot(1, 2, 2)
    librosa.display.waveshow(denoised_segments[0], sr=sr)
    plt.title("Denoised Segment (First Chunk)")
    plt.tight_layout()
    plt.show()
    
    # Plot the full waveform comparison
    y_noisy_full, _ = librosa.load(input_wav_path, sr=sr)
    plt.figure(figsize=(14, 6))
    plt.subplot(2, 1, 1)
    librosa.display.waveshow(y_noisy_full, sr=sr)
    plt.title("Full Noisy Audio")
    plt.subplot(2, 1, 2)
    librosa.display.waveshow(y_denoised_full, sr=sr)
    plt.title("Full Denoised Audio (Smoothed)")
    plt.tight_layout()
    plt.show()

# %%
# Provide paths for a demonstration file (change these as needed)
filename='noisy_sample.wav'
demo_dir = 'Demo'
demo_noisy_path = f"./{filename}"
demo_output_path = f"./{demo_dir}/{filename}"

# Ensure the demo directory exists
os.makedirs(f"./{demo_dir}", exist_ok=True)

# Process the full long file
denoise_audio_full(demo_noisy_path, demo_output_path, model, sr=SR, chunk_duration=3, gain=50, n_iter=64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8 os.makedirs(f"./{demo_dir}", exist_ok=True)
#      10 # Process the full long file
# ---> 11 denoise_audio_full(demo_noisy_path, demo_output_path, model, sr=SR, chunk_duration=3, gain=50, n_iter=64)
#
# NameError: name 'denoise_audio_full' is not defined
